# %% [markdown]
# **About the Data**
#
# The dataset used for this project is a subset of the LendingClub DataSet obtained from Kaggle: https://www.kaggle.com/wordsforthewise/lending-club
#
# ##The dataset is a modified version of the original dataset to perform some extra feature engineering.
# LendingClub is a US peer-to-peer lending company, headquartered in San Francisco, California. It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market. LendingClub is the world's largest peer-to-peer lending platform.
#
# ##Our Goal
#
# Given historical data on loans given out with information on whether or not the borrower defaulted (charge-off), we aim to build a deep learning model that can predict wether or nor a borrower will pay back their loan? This way in the future when we get a new potential customer we can assess whether or not they are likely to pay back the loan.

# %% [markdown]
# **Start with importing all the modules and libraries.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **'lending_club_info.csv' contains description of all the columns/features of the dataset.**

# %%
data_info = pd.read_csv("/Users/akshayshendre/Desktop/Apploan/data/lending_club_info.csv", index_col='LoanStatNew')
data_info
# Out:
#                                                             Description
# LoanStatNew
# loan_amnt             The listed amount of the loan applied for by t...
# term                  The number of payments on the loan. Values are...
# int_rate                                      Interest Rate on the loan
# installment           The monthly payment owed by the borrower if th...
# grade                                            LC assigned loan grade
# sub_grade                                     LC assigned loan subgrade
# emp_title             The job title supplied by the Borrower when ap...
# emp_length            Employment length in years. Possible values ar...
# home_ownership        The home ownership status provided by the borr...
# annual_inc            The self-reported annual income provided by th...
# verification_status   Indicates if income was verified by LC, not ve...
# issue_d                             The month which the loan was funded
# loan_status                                  Current status of the loan
# purpose               A category provided by the borrower for the lo...
# title                           The loan title provided by the borrower
# zip_code              The first 3 numbers of the zip code provided b...
# addr_state            The state provided by the borrower in the loan...
# dti                   A ratio calculated using the borrower’s total ...
# earliest_cr_line      The month the borrower's earliest reported cre...
# open_acc              The number of open credit lines in the borrowe...
# pub_rec                             Number of derogatory public records
# revol_bal                                Total credit revolving balance
# revol_util            Revolving line utilization rate, or the amount...
# total_acc             The total number of credit lines currently in ...
# initial_list_status   The initial listing status of the loan. Possib...
# application_type      Indicates whether the loan is an individual ap...
# mort_acc                                   Number of mortgage accounts.
# pub_rec_bankruptcies               Number of public record bankruptcies

# %%
print(data_info.loc['loan_amnt']["Description"])
# Out:
# The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.

# %%
#function to get the feature info

# %%
def info(col):
    return data_info.loc[col]["Description"]

# %%
info("loan_amnt")
# Out:
# 'The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.'

# %% [markdown]
# ## Loading the data

# %%
data = pd.read_csv("/Users/akshayshendre/Desktop/Apploan/data/lending_club_loan_two.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
#  14  title                 394274 non-null  object
#  15  dti                   396030 non-null  float64
#  16  earliest_cr_line      396030 non-null  object
#  17  open_acc              396030 non-null  float64
#  18  pub_rec               396030 non-null  float64
#  19  revol_bal             396030 non-null  float64
#  20  revol_util            395754 non-null  float64
#  21  total_acc             396030 non-null  float64
#  22  initial_list_status   396030 non-null  object
#  23  application_type      396030 non-null  object
#  24  mort_acc              358235 non-null  float64
#  25  pub_rec_bankruptcies  395495 non-null  float64
#  26  address               396030 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %%
#396030 entries and 27 columns/Features including target

# %%
data.describe().T
# Out:
#                          count          mean           std     min       25%  \
# loan_amnt             396030.0  14113.888089   8357.441341  500.00   8000.00
# int_rate              396030.0     13.639400      4.472157    5.32     10.49
# installment           396030.0    431.849698    250.727790   16.08    250.33
# annual_inc            396030.0  74203.175798  61637.621158    0.00  45000.00
# dti                   396030.0     17.379514     18.019092    0.00     11.28
# open_acc              396030.0     11.311153      5.137649    0.00      8.00
# pub_rec               396030.0      0.178191      0.530671    0.00      0.00
# revol_bal             396030.0  15844.539853  20591.836109    0.00   6025.00
# revol_util            395754.0     53.791749     24.452193    0.00     35.80
# total_acc             396030.0     25.414744     11.886991    2.00     17.00
# mort_acc              358235.0      1.813991      2.147930    0.00      0.00
# pub_rec_bankruptcies  395495.0      0.121648      0.356174    0.00      0.00
#
#                            50%       75%         max
# loan_amnt             12000.00  20000.00    40000.00
# int_rate                 13.33     16.49       30.99
# installment             375.43    567.30     1533.81
# annual_inc            64000.00  90000.00  8706582.00
# dti                      16.91     22.98     9999.00
# open_acc                 10.00     14.00       90.00
# pub_rec                   0.00      0.00       86.00
# revol_bal             11181.00  19620.00  1743266.00
# revol_util               54.80     72.90      892.30
# total_acc                24.00     32.00      151.00
# mort_acc                  1.00      3.00       34.00
# pub_rec_bankruptcies      0.00      0.00        8.00

# %%
data.head(2).T
# Out:
#                                                                  0  \
# loan_amnt                                                  10000.0
# term                                                     36 months
# int_rate                                                     11.44
# installment                                                 329.48
# grade                                                            B
# sub_grade                                                       B4
# emp_title                                                Marketing
# emp_length                                               10+ years
# home_ownership                                                RENT
# annual_inc                                                117000.0
# verification_status                                   Not Verified
# issue_d                                                   Jan-2015
# loan_status                                             Fully Paid
# purpose                                                   vacation
# title                                                     Vacation
# dti                                                          26.24
# earliest_cr_line                                          Jun-1990
# open_acc                                                      16.0
# pub_rec                                                        0.0
# revol_bal                                                  36369.0
# revol_util                                                    41.8
# total_acc                                                     25.0
# initial_list_status                                              w
# application_type                                        INDIVIDUAL
# mort_acc                                                       0.0
# pub_rec_bankruptcies                                           0.0
# address               0174 Michelle Gateway\nMendozaberg, OK 22690
#
#                                                                     1
# loan_amnt                                                      8000.0
# term                                                        36 months
# int_rate                                                        11.99
# installment                                                    265.68
# grade                                                               B
# sub_grade                                                          B5
# emp_title                                             Credit analyst
# emp_length                                                    4 years
# home_ownership                                               MORTGAGE
# annual_inc                                                    65000.0
# verification_status                                      Not Verified
# issue_d                                                      Jan-2015
# loan_status                                                Fully Paid
# purpose                                            debt_consolidation
# title                                              Debt consolidation
# dti                                                             22.05
# earliest_cr_line                                             Jul-2004
# open_acc                                                         17.0
# pub_rec                                                           0.0
# revol_bal                                                     20131.0
# revol_util                                                       53.3
# total_acc                                                        27.0
# initial_list_status                                                 f
# application_type                                           INDIVIDUAL
# mort_acc                                                          3.0
# pub_rec_bankruptcies                                              0.0
# address               1076 Carney Fort Apt. 347\nLoganmouth, SD 05113

# %% [markdown]
# # Exploratory Data Analysis
#
# Goal of the analysis is to understand which features are important, view summary statistics, and visualize the data.
#
# ----

# %% [markdown]
# **Since the goal is to predict loan_status, we will start with looking at the counts of 'Fully paid' and 'Charged off' values in the dataset.**

# %%
sns.countplot(x="loan_status", data = data);

# %% [markdown]
# **Looking at the distribution of loan_amnt.**

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(6,5))
sns.histplot(x="loan_amnt", data = data, alpha=0.5, bins = 50)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Now let's explore correlation between the numerical features.**

# %%
data.select_dtypes(include="object").columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'purpose', 'title', 'earliest_cr_line', 'initial_list_status',
#        'application_type', 'address'],
#       dtype='object')

# %%
data.select_dtypes(include="number").columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'mort_acc',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
data.corr(numeric_only=True)
# Out:
#                       loan_amnt  int_rate  installment  annual_inc       dti  \
# loan_amnt              1.000000  0.168921     0.953929    0.336887  0.016636
# int_rate               0.168921  1.000000     0.162758   -0.056771  0.079038
# installment            0.953929  0.162758     1.000000    0.330381  0.015786
# annual_inc             0.336887 -0.056771     0.330381    1.000000 -0.081685
# dti                    0.016636  0.079038     0.015786   -0.081685  1.000000
# open_acc               0.198556  0.011649     0.188973    0.136150  0.136181
# pub_rec               -0.077779  0.060986    -0.067892   -0.013720 -0.017639
# revol_bal              0.328320 -0.011280     0.316455    0.299773  0.063571
# revol_util             0.099911  0.293659     0.123915    0.027871  0.088375
# total_acc              0.223886 -0.036404     0.202430    0.193023  0.102128
# mort_acc               0.222315 -0.082583     0.193694    0.236320 -0.025439
# pub_rec_bankruptcies  -0.106539  0.057450    -0.098628   -0.050162 -0.014558
#
#                       open_acc   pub_rec  revol_bal  revol_util  total_acc  \
# loan_amnt             0.198556 -0.077779   0.328320    0.099911   0.223886
# int_rate              0.011649  0.060986  -0.011280    0.293659  -0.036404
# installment           0.188973 -0.067892   0.316455    0.123915   0.202430
# annual_inc            0.136150 -0.013720   0.299773    0.027871   0.193023
# dti                   0.136181 -0.017639   0.063571    0.088375   0.102128
# open_acc              1.000000 -0.018392   0.221192   -0.131420   0.680728
# pub_rec              -0.018392  1.000000  -0.101664   -0.075910   0.019723
# revol_bal             0.221192 -0.101664   1.000000    0.226346   0.191616
# revol_util           -0.131420 -0.075910   0.226346    1.000000  -0.104273
# total_acc             0.680728  0.019723   0.191616   -0.104273   1.000000
# mort_acc              0.109205  0.011552   0.194925    0.007514   0.381072
# pub_rec_bankruptcies -0.027732  0.699408  -0.124532   -0.086751   0.042035
#
#                       mort_acc  pub_rec_bankruptcies
# loan_amnt             0.222315             -0.106539
# int_rate             -0.082583              0.057450
# installment           0.193694             -0.098628
# annual_inc            0.236320             -0.050162
# dti                  -0.025439             -0.014558
# open_acc              0.109205             -0.027732
# pub_rec               0.011552              0.699408
# revol_bal             0.194925             -0.124532
# revol_util            0.007514             -0.086751
# total_acc             0.381072              0.042035
# mort_acc              1.000000              0.027239
# pub_rec_bankruptcies  0.027239              1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(numeric_only=True),cmap="viridis", annot=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **We can observe almost perfect correlation of 'loan_amt' with the "installment" feature. Lets explore the correlation further using scatterplot.**

# %%
info("installment")
# Out:
# 'The monthly payment owed by the borrower if the loan originates.'

# %%
sns.jointplot(x="installment", y="loan_amnt", data=data, color="red", ylim=(0,45000));

# %%
# It was expected to have a positive correlation of installment with loan_amt as larger the loan_amt, larger will be its installment.

# %% [markdown]
# **Relationship between the loan_status and the Loan Amount.**

# %%
sns.boxplot(x="loan_status",y="loan_amnt",data=data);

# %% [markdown]
# **Summary statistics for the loan amount, grouped by the loan_status.**

# %%
data.groupby("loan_status")["loan_amnt"].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  20000.0  40000.0
# Fully Paid   19225.0  40000.0

# %% [markdown]
# **Let's explore the Grade and SubGrade columns to find out the unique possible grades and subgrades?**

# %%
array= list(data["grade"].sort_values().unique())

# %%
array
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
sub_array= list(data["sub_grade"].sort_values().unique())

# %%
sub_array
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'G1',
#  'G2',
#  'G3',
#  'G4',
#  'G5']

# %% [markdown]
# **Countplot for grade and subgrades with hue of loan_status.**

# %%
sns.countplot(x="grade", data= data, hue ="loan_status");

# %%
plt.figure(figsize=(7,3))
sns.countplot(x="sub_grade", data=data, order=sub_array)
plt.tight_layout()

# %%
plt.figure(figsize=(10,3))
sns.countplot(x="sub_grade", data=data, hue="loan_status",order=sub_array)
plt.tight_layout()

# %% [markdown]
# **It looks like F and G subgrades are not visible properly and seems like they are not paid often hence plot count plot for subgroup F and G alone.**

# %%
points = sorted(data[(data["grade"] == "F")| (data["grade"] == "G")]["sub_grade"].unique())

# %%
plt.figure(figsize=(10,3))
sns.countplot(x="sub_grade", data= data, order=points, hue="loan_status");

# %% [markdown]
# **Now we should look for the important feature variable and for that we must convert loan_status into numerical data. for that we will create a new column'loan_repaid' which will contain a 1 if the loan status was "Fully Paid" and a 0 if it was "Charged Off".**

# %%
data["loan_repaid"] = data["loan_status"].map({"Fully Paid":1,"Charged Off":0})

# %% [markdown]
# **Correlation of loan_repaid with other numerical feature variables sorted in negative to positive correlation**

# %%
sns.set_style("darkgrid")
data.corr(numeric_only=True)["loan_repaid"][:-1].sort_values().plot(kind="bar");

# %% [markdown]
# **Further visualising the plots of different features with hue of loan_repaid.**

# %%
sns.scatterplot(y="int_rate", x="loan_amnt",hue="loan_status",data=data);
# Out:
# /Users/akshayshendre/Library/Python/3.11/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /Users/akshayshendre/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data["annual_inc"].max()
# Out:
# 8706582.0

# %%
sns.displot(x='mort_acc', data=data,bins=20, hue="loan_status")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ---
#
# # Data PreProcessing
#
# **After visualising the data in this section we will try to deal with the missing data, remove unnecessary or repetitive features and will perform some feature engineering to convert categorical data into numerical form accordingly.**
#
# ---

# %%
df = data.copy()

# %%
df.head(5)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ... pub_rec  \
# 0                Marketing  10+ years           RENT    117000.0  ...     0.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...     0.0
# 2             Statistician   < 1 year           RENT     43057.0  ...     0.0
# 3          Client Advocate    6 years           RENT     54000.0  ...     0.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...     0.0
#
#   revol_bal revol_util total_acc initial_list_status  application_type  \
# 0   36369.0       41.8      25.0                   w        INDIVIDUAL
# 1   20131.0       53.3      27.0                   f        INDIVIDUAL
# 2   11987.0       92.2      26.0                   f        INDIVIDUAL
# 3    5472.0       21.5      13.0                   f        INDIVIDUAL
# 4   24584.0       69.8      43.0                   f        INDIVIDUAL
#
#   mort_acc  pub_rec_bankruptcies  \
# 0      0.0                   0.0
# 1      3.0                   0.0
# 2      0.0                   0.0
# 3      0.0                   0.0
# 4      1.0                   0.0
#
#                                            address  loan_repaid
# 0     0174 Michelle Gateway\nMendozaberg, OK 22690            1
# 1  1076 Carney Fort Apt. 347\nLoganmouth, SD 05113            1
# 2  87025 Mark Dale Apt. 269\nNew Sabrina, WV 05113            1
# 3            823 Reid Ford\nDelacruzside, MA 00813            1
# 4             679 Luna Roads\nGreggshire, VA 11650            0
#
# [5 rows x 28 columns]

# %% [markdown]
# # Missing Data
#
# **Let's explore this missing data columns.**

# %%
print(len(df))
# Out:
# 396030

# %% [markdown]
# **Total count of missing values per column.**

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %% [markdown]
# **Converting in term of percentage of the total DataFrame**

# %%
100*(df.isnull().sum()/len(df))
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443401
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# dtype: float64

# %% [markdown]
# **As we can see the highest percent of feature with missing values is 5.7 and 4.6% for emp_title and emp_length.**

# %% [markdown]
# **Let's examine emp_title and emp_length to see whether it will be okay to drop them.**

# %%
# first let's check the discription of the columns using info function

print(info("emp_title"))
print("\n")
print(info("emp_length"))
# Out:
# The job title supplied by the Borrower when applying for the loan.*
#
#
# Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %% [markdown]
# **Number of unique employment job titles?**

# %%
df["emp_title"].nunique()
# Out:
# 173105

# %%
df["emp_title"].value_counts()
# Out:
# emp_title
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: count, Length: 173105, dtype: int64

# %% [markdown]
# **There are too many unique job titles to try to convert this to a dummy variable feature. Hence we will move on to remove that emp_title column.**

# %%
df.drop("emp_title", axis=1,inplace=True)

# %%
df.head(1)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade emp_length  \
# 0    10000.0   36 months     11.44       329.48     B        B4  10+ years
#
#   home_ownership  annual_inc verification_status  ... pub_rec revol_bal  \
# 0           RENT    117000.0        Not Verified  ...     0.0   36369.0
#
#   revol_util total_acc  initial_list_status application_type  mort_acc  \
# 0       41.8      25.0                    w       INDIVIDUAL       0.0
#
#    pub_rec_bankruptcies                                       address  \
# 0                   0.0  0174 Michelle Gateway\nMendozaberg, OK 22690
#
#    loan_repaid
# 0            1
#
# [1 rows x 27 columns]

# %% [markdown]
# **The 'emp_length' feature column.**

# %%
df["emp_length"].nunique()
# Out:
# 11

# %%
sort= df["emp_length"].value_counts().sort_values(ascending=False)
sort
# Out:
# emp_length
# 10+ years    126041
# 2 years       35827
# < 1 year      31725
# 3 years       31665
# 5 years       26495
# 1 year        25882
# 4 years       23952
# 6 years       20841
# 7 years       20819
# 8 years       19168
# 9 years       15314
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="emp_length", data=df)
plt.tight_layout()

# %% [markdown]
# **The countplot with a hue of loan_status**

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="emp_length", data=df, hue="loan_status")
plt.tight_layout()

# %% [markdown]
# **This still doesn't really informs if there is a strong relationship between employment length and being charged off, hence we want the percentage of charge offs per category. This will tell us the percent of people per employment category didn't pay back their loan.**

# %%
a = df[df["loan_status"]=="Fully Paid"]["emp_length"].value_counts()

# %%
b= df[df["loan_status"]=="Charged Off"]["emp_length"].value_counts()

# %%
c= b/a

# %%
c
# Out:
# emp_length
# 1 year       0.248649
# 10+ years    0.225770
# 2 years      0.239560
# 3 years      0.242593
# 4 years      0.238213
# 5 years      0.237911
# 6 years      0.233341
# 7 years      0.241887
# 8 years      0.249625
# 9 years      0.250735
# < 1 year     0.260830
# Name: count, dtype: float64

# %%
c.plot(kind="bar");

# %%
d= df["emp_length"].value_counts()
e= b/d
e.plot(kind="bar");

# %% [markdown]
# **Charge off rates are extremely similar across all employment lengths hence we will drop the emp_length column.**

# %%
df.drop("emp_length",axis=1,inplace=True)

# %%
df.head().T
# Out:
#                                                                  0  \
# loan_amnt                                                  10000.0
# term                                                     36 months
# int_rate                                                     11.44
# installment                                                 329.48
# grade                                                            B
# sub_grade                                                       B4
# home_ownership                                                RENT
# annual_inc                                                117000.0
# verification_status                                   Not Verified
# issue_d                                                   Jan-2015
# loan_status                                             Fully Paid
# purpose                                                   vacation
# title                                                     Vacation
# dti                                                          26.24
# earliest_cr_line                                          Jun-1990
# open_acc                                                      16.0
# pub_rec                                                        0.0
# revol_bal                                                  36369.0
# revol_util                                                    41.8
# total_acc                                                     25.0
# initial_list_status                                              w
# application_type                                        INDIVIDUAL
# mort_acc                                                       0.0
# pub_rec_bankruptcies                                           0.0
# address               0174 Michelle Gateway\nMendozaberg, OK 22690
# loan_repaid                                                      1
#
#                                                                     1  \
# loan_amnt                                                      8000.0
# term                                                        36 months
# int_rate                                                        11.99
# installment                                                    265.68
# grade                                                               B
# sub_grade                                                          B5
# home_ownership                                               MORTGAGE
# annual_inc                                                    65000.0
# verification_status                                      Not Verified
# issue_d                                                      Jan-2015
# loan_status                                                Fully Paid
# purpose                                            debt_consolidation
# title                                              Debt consolidation
# dti                                                             22.05
# earliest_cr_line                                             Jul-2004
# open_acc                                                         17.0
# pub_rec                                                           0.0
# revol_bal                                                     20131.0
# revol_util                                                       53.3
# total_acc                                                        27.0
# initial_list_status                                                 f
# application_type                                           INDIVIDUAL
# mort_acc                                                          3.0
# pub_rec_bankruptcies                                              0.0
# address               1076 Carney Fort Apt. 347\nLoganmouth, SD 05113
# loan_repaid                                                         1
#
#                                                                     2  \
# loan_amnt                                                     15600.0
# term                                                        36 months
# int_rate                                                        10.49
# installment                                                    506.97
# grade                                                               B
# sub_grade                                                          B3
# home_ownership                                                   RENT
# annual_inc                                                    43057.0
# verification_status                                   Source Verified
# issue_d                                                      Jan-2015
# loan_status                                                Fully Paid
# purpose                                                   credit_card
# title                                         Credit card refinancing
# dti                                                             12.79
# earliest_cr_line                                             Aug-2007
# open_acc                                                         13.0
# pub_rec                                                           0.0
# revol_bal                                                     11987.0
# revol_util                                                       92.2
# total_acc                                                        26.0
# initial_list_status                                                 f
# application_type                                           INDIVIDUAL
# mort_acc                                                          0.0
# pub_rec_bankruptcies                                              0.0
# address               87025 Mark Dale Apt. 269\nNew Sabrina, WV 05113
# loan_repaid                                                         1
#
#                                                           3  \
# loan_amnt                                            7200.0
# term                                              36 months
# int_rate                                               6.49
# installment                                          220.65
# grade                                                     A
# sub_grade                                                A2
# home_ownership                                         RENT
# annual_inc                                          54000.0
# verification_status                            Not Verified
# issue_d                                            Nov-2014
# loan_status                                      Fully Paid
# purpose                                         credit_card
# title                               Credit card refinancing
# dti                                                     2.6
# earliest_cr_line                                   Sep-2006
# open_acc                                                6.0
# pub_rec                                                 0.0
# revol_bal                                            5472.0
# revol_util                                             21.5
# total_acc                                              13.0
# initial_list_status                                       f
# application_type                                 INDIVIDUAL
# mort_acc                                                0.0
# pub_rec_bankruptcies                                    0.0
# address               823 Reid Ford\nDelacruzside, MA 00813
# loan_repaid                                               1
#
#                                                          4
# loan_amnt                                          24375.0
# term                                             60 months
# int_rate                                             17.27
# installment                                         609.33
# grade                                                    C
# sub_grade                                               C5
# home_ownership                                    MORTGAGE
# annual_inc                                         55000.0
# verification_status                               Verified
# issue_d                                           Apr-2013
# loan_status                                    Charged Off
# purpose                                        credit_card
# title                                Credit Card Refinance
# dti                                                  33.95
# earliest_cr_line                                  Mar-1999
# open_acc                                              13.0
# pub_rec                                                0.0
# revol_bal                                          24584.0
# revol_util                                            69.8
# total_acc                                             43.0
# initial_list_status                                      f
# application_type                                INDIVIDUAL
# mort_acc                                               1.0
# pub_rec_bankruptcies                                   0.0
# address               679 Luna Roads\nGreggshire, VA 11650
# loan_repaid                                              0

# %% [markdown]
# **Again revisiting the DataFrame to see what feature columns still have missing data.**

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cmap="viridis", yticklabels=False,cbar=False );

# %% [markdown]
# **The purpose & title column**

# %%
list(df["purpose"].unique())
# Out:
# ['vacation',
#  'debt_consolidation',
#  'credit_card',
#  'home_improvement',
#  'small_business',
#  'major_purchase',
#  'other',
#  'medical',
#  'wedding',
#  'car',
#  'moving',
#  'house',
#  'educational',
#  'renewable_energy']

# %%
list(df["title"].unique())
# Out:
# ['Vacation',
#  'Debt consolidation',
#  'Credit card refinancing',
#  'Credit Card Refinance',
#  'Home improvement',
#  'No More Credit Cards',
#  'Debt Consolidation',
#  'Business',
#  'Major purchase',
#  'Debt Consolidation/Home Repairs',
#  'kawasaki jetski',
#  'Medical and Post Graduate Education Expenses',
#  'Credit card debt',
#  'concolidation',
#  'Consolidation Loan',
#  'Consolidate debt',
#  'Pay Off Credit Card',
#  'Cover',
#  'Making a difference',
#  'Debt Consalidation',
#  'Thank you for your help!',
#  'Medical expenses',
#  'debt consolidation',
#  'Other',
#  'Dental Work',
#  'Dept Consolodation/Home Improvement',
#  'Want to be debt free in "3"',
#  'Moving Forward',
#  'Bills',
#  'Honost Consolidation',
#  'home expenses',
#  'Pay the Bills',
#  'Debt Loan',
#  'Car financing',
#  'Moving and relocation',
#  'Home buying',
#  'credit card refinance loan',
#  'Moving Payoff',
#  'Small Business Loan - Gourmet Food Truck',
#  'consolidation loan',
#  'first loan',
#  'Personal',
#  'Consolidation',
#  'Loan',
#  'The trailer',
#  'Fiscal Responsibility',
#  'creditbuild1',
#  'Consolidation ',
#  'consolidation',
#  'FREEDOM 2',
#  'Home Improvement',
#  'Debt Consolodation',
#  'Credit Consal.',
#  'Lets go on vacation & do the kitchen',
#  'Debt Consolidation for Family',
#  '2bettermylife',
#  'DebtConsolidation',
#  'Credit card pay off',
#  'temp',
#  'consolidate',
#  'Ducks in a Row',
#  'Home project',
#  'TIME FOR CHANGE',
#  'Bill Consolidation and flooring',
#  'DEBT CONSOLIDATION',
#  'Credit card relief',
#  'Wedding Loan',
#  'Big loan',
#  'payoff',
#  'Debt con',
#  'Debt Destruction',
#  'debt payment',
#  '\tother',
#  'Lesson Learned Credit Cards',
#  'helful loan',
#  'Moving and Debt Consolidation',
#  'credit reduction',
#  'consolidate bills',
#  'My Payoff Loan',
#  'Debt Consol',
#  'Home renovation',
#  'Consolidation1',
#  'cc refinance',
#  'Pay Down the Cards',
#  'Lowering My Interest Rate',
#  'My 5-year plan to being debt free!',
#  'home improvements',
#  'buissness',
#  'Card Card Payoff',
#  'Fix my House',
#  'Credit Cards',
#  'One Payment',
#  'great consolidation',
#  'New beginning',
#  'medical expenses/credit card',
#  'Clean-Up',
#  'pay off my debt',
#  'refi',
#  'Lending Club Debt Consolidation',
#  'No More Credit Card Debt!',
#  'Planning to pay off in less than 3 yrs',
#  'Wedding ',
#  'Debt Consolidation Loan',
#  'Major Purchase',
#  'consoladate',
#  'Pay Bills',
#  'Demolish Credit Card Debt',
#  'Lconsolidate',
#  'CC Consolidate',
#  'Acting',
#  'MyLoan',
#  'bye bye credit cards',
#  'Short term loan for wedding expenses',
#  'Arctic spa loan',
#  'Consolidated Freedom',
#  'Credit Card Consolidation',
#  'free',
#  'Credit Card Debt Consolidation',
#  'Personal 2013',
#  'Home Love',
#  'debt_consolidation',
#  'Consolidate',
#  'Loan 1',
#  'waterproof crawl space/replace AC',
#  'HOME IMPROVEMENT',
#  'JB 2010 Debt Consolidation Loan',
#  'credit cards',
#  'CC Loan',
#  'Credit Payoff',
#  'home improvement',
#  'Credit Card Debt Payments',
#  'No Moan Loan',
#  'Credit loan',
#  'Installment Loan',
#  ' Debt Consolidation Loan',
#  'Get out of debt already!',
#  'CC Debt',
#  'Credit cards paid off',
#  'creditcard payoff',
#  'Pay off',
#  'Credit Card refinance',
#  'Credit Card payoff',
#  'Improvement',
#  'homefree',
#  'Medical Loan',
#  'CONSOLIDATION',
#  'Debt consoidation',
#  'auto finance ',
#  'CC Consolidation',
#  'Trailer',
#  'Debt Consolidate',
#  'CC',
#  'Credit card payoff',
#  'Debt Payoff',
#  'My Home',
#  'Paying off credit cards',
#  'Home Renovation',
#  'Miramar Loan',
#  nan,
#  'My Way Out',
#  'Credit cards',
#  'Vega',
#  'second',
#  'Student Loan',
#  'Lending Club',
#  '2011 Credit Card Payoff',
#  'Out of debt loan.',
#  'Car',
#  'Credit Card',
#  'freedom',
#  'INCOGNITO',
#  'home remodel',
#  'Refinance',
#  'pay it all off!',
#  'Debt Pay Off',
#  '10',
#  'short term help',
#  'Relief',
#  'debt free shortly',
#  'discover consolidation loan',
#  'stress relief',
#  'debt ',
#  'A/C Repair',
#  'debtdone',
#  'refinance',
#  'debt consolidation ',
#  'payoff ',
#  'Money Smart loan',
#  'Freedom',
#  'Just cleaning up ',
#  'High interest credit card',
#  'Car loan ',
#  'Credit Card Refinincing',
#  'PAGOS DE TARJETAS',
#  'Betterisoneday',
#  'debtconsolidation',
#  'Debt payoff plan',
#  'First personal loan',
#  'my kitchen',
#  'credit card freedom loan',
#  'Consolidating Loan',
#  'Credit card pay-off',
#  're-finance',
#  'CreditCardPay',
#  'High and Steady Income (Car Improvement)',
#  'Relief Spa',
#  'Debt Consolidation Loan Request',
#  '12k 16.5%',
#  'Consolidate 2 credit cards to low rate',
#  'Proven Borrower with Strong Track Record',
#  'Budget keeper',
#  '$10,000 Loan',
#  'Debit Payoff',
#  'garage',
#  'Financial Emergency',
#  'My Lending Club Loan',
#  'Credit refi',
#  'debt consolidation loan',
#  'Bill Pay Off',
#  'Race car',
#  'Auto Loan',
#  'debteraser',
#  'MY PROGRESS',
#  'no postage necessary',
#  'credit card refi',
#  'Debt consolidation ',
#  'Good credit/ income. short term loan',
#  'B of A CC Refinance',
#  'DEBT C',
#  'Driveway loan',
#  'Debt Consolidation ',
#  'freedom loan',
#  'Paying off the car and some bills',
#  'Blessed',
#  'Personal loan',
#  'backhoe',
#  'Credit Card consolidatiton',
#  'OperationDC',
#  'Bill Consolidation',
#  'Payoff',
#  'Pay off Citibank Visa',
#  'Home Entertainment System',
#  'Road to Healthier Finances',
#  'Consolidated my debt to one payment  ',
#  'For what ever comes up',
#  'pay off ',
#  'LendingClub',
#  'Credit Card Loan',
#  'Credit Card Payoff',
#  'lower interest rate loan',
#  'cleanslate',
#  'freshstart',
#  'pERSONAL lOAN',
#  'Freedom Loan ',
#  'credit card consolidationconsolidation',
#  'Consolidation - Vacation Expenditures',
#  'Home improvent',
#  'credit card refinance',
#  'want to say goodbye to credit cards',
#  'Sleep At Night',
#  'Invest Here! Reliable Borrower',
#  'Credit Card Killer',
#  'CC Payoff',
#  'Credit card consolidation',
#  'Debt Buster',
#  'New start',
#  'POOL',
#  'credit card',
#  'Pool',
#  'my loan',
#  'Pay Credit Card',
#  'Small Business Loan',
#  'FAMILY LOAN',
#  'Freedom ',
#  'OVERDUE VACATION',
#  'Transmission Rebuild Loan',
#  'amazing',
#  'Spring Cleaning ',
#  'Consolidation loan',
#  'Myloan',
#  'Debit ',
#  'consolidation-2 hi interest credit cards',
#  'debt consolidate',
#  'loan',
#  'credit card/loan consolidation',
#  'personal',
#  'credit card, consolidate and home improv',
#  'pay on time ',
#  'Credit Cards payoff',
#  'pay bills',
#  'Wedding Expenses',
#  'Consolidation Payment',
#  'LoanConsol2',
#  'Pay Off Credit Cards',
#  'Misc Bills Consolidation',
#  'Stability',
#  'Dependence',
#  'Get Out of Debt 2012',
#  'Pay off Chase CC',
#  'Ultimate Manuver',
#  'Working college grad trying to pay debt',
#  'Get rid of debt',
#  'Help pay off the last credit card',
#  'lifesaver',
#  'Car repai',
#  'personal Loan',
#  'Home Purchase',
#  'debt console',
#  'loan to pay consolidate my bills',
#  'Stop paying interest to Chase',
#  'Credit Card Payoff Loan',
#  'Swimming Pool Maintenance Loan',
#  'tryin hard to pay off credit cards',
#  'debt loan',
#  'pay off',
#  'Super loan 1',
#  'Success',
#  'Pay Off Credit Cards and Close Accounts',
#  'Get me out of debt!',
#  'Investment ',
#  'Personal Refi',
#  'Home Improvements ',
#  'Motorcycle Loan',
#  'Debt Blaster',
#  'Dream Wedding for my lil girl',
#  'get out of debt',
#  'Credit Card loan',
#  'CREDIT CARD PAYOFF',
#  'New Travel Trailer',
#  'Debit Consolidation',
#  'Wedding Bliss',
#  "Mike's Consolidation Loan",
#  'Credit Card Debt Refinancing',
#  'Personal Loan',
#  'PERSONAL LOAN',
#  'Debt Conslidation',
#  'Credit Card Consolidation Loan.',
#  'little freedom',
#  'MY WISH',
#  'Get a quick pauoff on this loan ',
#  'payoff loan',
#  'decreasemonthlypayments',
#  'Debt free',
#  'debt free',
#  'Debt',
#  'no more credit card',
#  'Credit card loan',
#  'credit card consolidation loan',
#  'credit card pay',
#  'Home Improvements',
#  'Pay off Loan',
#  'Buying a vehicle',
#  'home improvement ',
#  'Willow',
#  'Consolidate Bills',
#  'My Loan',
#  'CONSOLIDATE',
#  'Restructuring Debt & Home Repair',
#  'laura and greg loan',
#  'CC payoff',
#  'Self',
#  'Credit consolidation ',
#  'Bill consolidation',
#  'consolidation ',
#  'Small Business',
#  'Secure mine',
#  'Short Help Loan',
#  'credit',
#  'Let me pay you instead of big banks!',
#  'Finish off',
#  'Lower My Utilities - Go Green',
#  'irs payoff',
#  'home',
#  'Home Improvement Loan',
#  'Debt Consolodation Loan',
#  'noproblem',
#  'Debt eliminator',
#  'Credit Consolidation',
#  'My loan',
#  'Loan V',
#  'DebtCons',
#  'farm debt',
#  'home ',
#  'Consolidation 2',
#  'Auto Repair Loan',
#  'Credit Card Payment',
#  'Just Graduated, Paying Off Creditors',
#  'Fianancial Freedom',
#  'Debt consolidation opportunity',
#  'Debt Consolidation & Elimination ',
#  'Home',
#  'Payed off',
#  'LOAN POOL',
#  'givemeloan',
#  'good days ',
#  'Pay off credit card debt.',
#  'healthcare',
#  'Consolidation of Auto/Furniture Loans',
#  'vacation',
#  '2012 loan',
#  'DEBT CONSOLODATION LOAN',
#  'fresh start',
#  'Credit Card Refinance lower rate',
#  'PAYOFF',
#  'freedom from credit cards',
#  'Short investment loan',
#  'Fresh start ',
#  'Payoff plan',
#  'New Year, New Beginnings',
#  'Energy Reduction Loan',
#  'Debt Reduction and Savings Building',
#  'Back in Black',
#  "joni's loan",
#  'consolidate ',
#  'DEBT CONSOLIDATION LOAN',
#  'Consolation Loan',
#  'Refinancing Direct Merchants Bank',
#  'New Kitchen',
#  'Consolidating To a Fixed Lower Rate',
#  'First consolidate, then eliminate',
#  'Help Consolidating',
#  'bills',
#  'Kitchen and Bath',
#  'debtdiet',
#  'Triumph Loan',
#  'Credit Loan',
#  'Moving Loan',
#  'Loan ',
#  'Credit card Loan',
#  'Personal_1',
#  'loan0001',
#  'Credit Nuking',
#  'School',
#  'Condo Refinance',
#  'HouseFaceLift',
#  'Home Improvement ',
#  'the consolidator',
#  'feed me',
#  'Piece of mind',
#  'Paying off moving loan at lower rate',
#  'Credit card ',
#  'The big payoff',
#  'Short Term Loan',
#  'Major Purchase Loan',
#  'GetoutofDebt',
#  'pay off  creditcard',
#  'getting out from under medical/ccbills',
#  'Pay It Off!',
#  'Much Needed Loan',
#  'Pay-Off Santander Car Loan and New Roof',
#  'MyFuture',
#  'Whole in One',
#  'Medical Expense',
#  'payoff debt',
#  'debt free at last',
#  'Pay credit card',
#  'major purchase',
#  'Credit card refinance',
#  'Vacation Loan',
#  'Credit Card Refinancing',
#  'Gold Wing',
#  'CreditCardRefin',
#  'consolidaton',
#  'saving on interest',
#  'Payoffs',
#  'Debt be gone',
#  'debt payoff',
#  'personal loan',
#  'My Obligation',
#  'grandprix',
#  'Refi',
#  'New deck and landscaping',
#  'Consulting loan',
#  'AMEX payoff',
#  'pay cards',
#  'Citifinancial',
#  'heat pump & covered front porch',
#  'Debt Consolidation!',
#  'Debt Relief',
#  'Moving from Atlanta Fund',
#  'Wedding Breathing Room',
#  'New Me',
#  'pay my bills',
#  'Business Expansion',
#  'Refinance Credit Cards/Debts',
#  'credit card reconcile',
#  'Fresh Start Loan',
#  'Pay off Credit Cards',
#  'Down my Debt loan',
#  'personal home improvements',
#  'pay off credit cards',
#  'Goodbye to Debt',
#  'Credit Payment',
#  'DEBT FREE in 3 years!',
#  'Chase',
#  'get caught up',
#  'Pay off Credit cards',
#  'Debt Cons.',
#  'debt consol',
#  'bronco',
#  'My Personal Loan',
#  'easy pay',
#  'peaceofmind',
#  'Medical',
#  'Debt Consolidation loan',
#  'Debt consolidation loan ',
#  'Consolidate Debt',
#  'Debt Free (At Last)',
#  'Getting Me Back On My Feet Financially',
#  'La fin des cartes de credit',
#  'Credit Card Debt Loan',
#  'Clean Slate',
#  'make only one payment for all my card',
#  'Debt pay down',
#  'Getting Serious ',
#  'Debt Consolidation and Cleanup',
#  'Backyard Improvments',
#  'credit card payoff / home inprovement',
#  'PAY OFF CREDIT CARDS  ',
#  'Wedding',
#  'loan1',
#  'Home and credit',
#  'Capital one refi',
#  'blessed loan',
#  'DREAM CAR',
#  'bill consolidation',
#  'payoff credit cards',
#  'parkland',
#  'credit card help',
#  'pay credit cards',
#  'car finance',
#  'Debt Consolidation (Pay off Credit Cards',
#  'Responsible Borrower In Need!',
#  'lendtree',
#  'Pay off Debt',
#  'credit card freedom',
#  'unexpected home repair loan',
#  'Pay Off CC Loan',
#  'CreditCards',
#  'shed loan',
#  'Lending Club CC ReFi',
#  'Interior Improvements Loan',
#  'lower interest',
#  'BUSINESS LOAN',
#  'Truck',
#  'Debt payoff',
#  'Surgery',
#  'Credit Cards ',
#  'First Financial',
#  'BOA payoff',
#  'NO MORE CREDIT',
#  'REFINANCE CC DEBT BEFOR RATES GO WAY UP!!!!!',
#  '3rd loan,great company. Love LendingClub',
#  'Clean up debt loan',
#  'myway',
#  'HOME IMP',
#  'Making The Right Choice',
#  'Divorce',
#  'Home Improvment - New Roof (Leaking).',
#  'Credit Card Refi',
#  'BB consol',
#  'Siding and new windows',
#  'Lending Club Loan 1',
#  'Investment in Education.',
#  'Debt Reduction',
#  'Credit Card debt loan',
#  'New staff',
#  ' debt consolidation ',
#  'Credit card consolidation ',
#  'Paying off debt to save for a house',
#  'Fresh Start',
#  'helpful',
#  ' creditcard payoff',
#  'Debt Consilidation ',
#  '2013 Consolidation',
#  'DebtConsolidate',
#  'supllmentary laon',
#  'creditcardpayoff',
#  'no debt',
#  'debt cancellation',
#  'Lending Club Loan Refinance',
#  'car',
#  'Pay off US Bank credit cards!',
#  'CC refi',
#  'Back on track',
#  'Help Make My Dream A Reality',
#  'Fix my Debt Part 1',
#  'Moto Money',
#  'CC ReFi',
#  'Home  Improvement',
#  'Patio',
#  'Kitchen',
#  'Cardrefi',
#  'Debt Consolidation for Lower APR',
#  'Combine',
#  'Bill Payoff',
#  'Get out of Debt',
#  'I need to pay off all my credit cards.',
#  'necessary',
#  'Pay off credit cards',
#  'New Business Purchase',
#  'Web based business service - banking',
#  'GET OUT OF DEBT',
#  'Green loan',
#  'Hammering Down the Debt',
#  'Clear',
#  'new starrt',
#  'Freeatlast101',
#  'Home debt',
#  'intravenous sedation equipment',
#  'Table',
#  'atv',
#  'Auto_Payoff',
#  'ConsolLoan',
#  'Lending Club Loan',
#  'credit card refinanance',
#  'American express',
#  'Selling home closing costs/debt consolid',
#  'Credit debit',
#  'no more debt',
#  'Weddimg Loan',
#  'jeeploan2002',
#  'Get paid ',
#  'card Loan',
#  'ProsperityNow',
#  'creditcard refinance',
#  'Assistance',
#  'Personal Loan 3500',
#  'C Card',
#  'Freedom Acct',
#  'Excellent and Hard Worker, never missed a payment.',
#  'utv',
#  'Credit Refinance',
#  'steel building',
#  'Consolidating debt',
#  'kekekai2009',
#  'Peace',
#  'remodel',
#  'Vacation loan',
#  'D&G Estate Advance',
#  'My CC Payoff',
#  'pay it off',
#  'Home improve',
#  'tax relief ',
#  'Easy Money',
#  'fix up my home',
#  'Home repair',
#  'personal debt',
#  'bill pay off',
#  'Debt Elimination Loan',
#  'My Future',
#  'credit card payoff',
#  'Debt consolidation with lower interest ',
#  'Pool Heater Loan',
#  'Football',
#  'SRAMV',
#  'Business Loan with friends',
#  'A New Chapter',
#  'money for me',
#  'good work + pmt history for debt consol',
#  'debt consolitation loan',
#  'Credit Card consolidation/refinance ',
#  'free and clearf',
#  'Home improvements',
#  'Debt consolidaton for one payment',
#  'pay credit card',
#  'Refi Old Credit Cards',
#  'home repairs',
#  'Good for it',
#  'startup funding',
#  'Vehicle,and debt consolidation ',
#  'my home improvement ',
#  'major_purchase',
#  'business expansion',
#  'CC debt consolidation - home',
#  'Bills and Vacation',
#  'Debt Consolidation Loan ',
#  'DREAM LOAN',
#  'Moving loan',
#  'Fake Union',
#  'Lower Rate Loan',
#  'Barn building loan',
#  'basement remodel',
#  'Rental condo',
#  'payoff credit card',
#  'dept',
#  'Happiness',
#  'consilidation loan',
#  'my breakout loan',
#  'Peace of Mind',
#  'Three years out of debt',
#  'catching up',
#  'Pay-off Accelerator',
#  'Debt consolidation loan',
#  'credit card relief',
#  'Wedding expenses',
#  'Debts',
#  'Personal Loan - Debt Consolidation',
#  'Feb Loan',
#  'New Car Needed',
#  'ccrefi',
#  'Better Rate',
#  'Consolodation',
#  ' Debt Loan',
#  'debt',
#  'get rid of lowes',
#  'UTV',
#  'helphomeloan',
#  'credit card consolidation',
#  'Get Out of Debt',
#  'Pay off and Career Loan',
#  'creditcard',
#  'Credit Card Pay-Off and Home Improvement',
#  "A NYC Musician's Quest for Debt Freedom!",
#  'Credit Card consolidation',
#  'Lower Payment - More Possibilities',
#  'debt consoladation plus some for me',
#  'credit card pay off',
#  'Bills consolidation',
#  'Retainer Fee',
#  "Refi Wife's Credit Cards",
#  'CC Refinance',
#  'Plastic',
#  'emergency loan',
#  'freeofdebt',
#  'Refi Loan',
#  'Pay credit card balance',
#  'Moving forward',
#  'Moving & Relocation Loan',
#  'Pay Off Wedding',
#  'Debt Consolidation Daughter Wedding',
#  'Credit Card Debt Annihilation',
#  'House Remodel ',
#  'cashonhand',
#  'renovation',
#  'wedding',
#  'Personal Bridge Loan',
#  'Consolidation/medical',
#  'Operation Debt Clean Up',
#  'consolidate1',
#  'VACATION',
#  'Money in the bank',
#  'funiture',
#  'Better Rate Loan',
#  'Car stuff',
#  'Help Me Out',
#  'Med pay',
#  'Dakota',
#  'Credit payoff',
#  'creditconsolidate',
#  'Allinonepayment',
#  'above ground pool replacement',
#  'Cardfree',
#  'PAYMYDEBT',
#  'CardLine',
#  'Credit Card Refinance loan',
#  'Pay it off',
#  'Debt consolidation and home repair loan',
#  'wedding expenses',
#  'Debt Recovery',
#  'IVF',
#  'Natural gas upgrade',
#  'Pay off loan',
#  'Debt Consilidation',
#  'Get out of debt',
#  'The Great Payoff',
#  'pay off credit cards and auto loans',
#  'Loan 2 ',
#  'Replace second mortgage',
#  'homeimprovement',
#  'my finding  the way',
#  'fast loan ever, simple and easy.',
#  'project me',
#  'A better future ',
#  'New home India',
#  'see end of payments',
#  'Medical Bills and Urgent Appliance Probs',
#  'New Heat Pump',
#  'cash flow for business',
#  'Consolidate ',
#  'one payment',
#  'A Win-Win Loan',
#  'School and Debt payments',
#  'Credit Refi',
#  'CC LC Loan',
#  'HomeLoan',
#  'Start The New Year Right.',
#  'Credit consolidation',
#  'Future',
#  'Can Do',
#  'moneyforbills',
#  'Credit Card Consolidation Plan',
#  'Short Term Medical Loan',
#  'Fix Rate',
#  'Home loan',
#  'Debt consolidation before Grad school',
#  'pool',
#  'Repaying Retail Therapy Sessions',
#  'One Time Payoff',
#  'Too Cute',
#  'Cutting up the cards',
#  're-structuring loan',
#  'FIT startup loan',
#  'Cc refi',
#  'loan2012',
#  'Refinance Loan',
#  'the right thing to do.',
#  'CREDIT CARDS',
#  'Credit Card Debt Pay Off',
#  'BF Consolidation Loan',
#  'Consolidating Credit Cards',
#  'cards',
#  'State tax',
#  'CC Debt Consolidation',
#  'Solid Investment',
#  'payoff high intrest credit cards',
#  'byebyecreditcards',
#  'DebtConsol',
#  'Get It Together',
#  'Credit Refinance plan',
#  'Trustworthy Profession Loan',
#  'CCRefi',
#  'Car Loan',
#  ' Credit Card Consolidation  ',
#  'improving quality of life ',
#  'Pay Back Savings',
#  'Personnal Loan',
#  'Renovations',
#  'New Motorcycle',
#  'Motorcycle Purchase',
#  'Outdoor Upgrades',
#  'House payment',
#  'Mr. Downs',
#  'New Prospects Loan',
#  'Home Equity',
#  'swimming pool',
#  'Credit card refinance loan',
#  'Move to Michigan',
#  'Jorge Credit Card',
#  'Payoff 401K loan ',
#  'Consolidate loan',
#  'One Note',
#  'Loan for consolidating debt',
#  'Family Timeshare',
#  'debt and vacation',
#  'Loan2',
#  'All in one payment',
#  'New Loan',
#  'Debt loan',
#  'Loan1',
#  'wedding load',
#  'Refinance loan',
#  'debt consolidator',
#  'Buying a House',
#  'Small Debt Consolidation ',
#  'Credit Debt Consolidation',
#  'HVAC Repairs',
#  'Home Remodel',
#  'Auto loan',
#  'CreditCardPayoff',
#  'Pay off bills',
#  'my help',
#  'consolition',
#  'My relief',
#  'vw auto loan',
#  'My loans',
#  'JK loan',
#  'pay off bills and bilud a deck on the ho',
#  'Zx',
#  'camp improvement',
#  'Home Down Payment',
#  'Life cast spa',
#  'CC pay OFF',
#  'L. Club payoff ',
#  'Pool Loan',
#  'Personal Loan to consolidate Loan',
#  'Tahoe Loan',
#  'debtloan',
#  'Lending Loan',
#  'saying bye to credit cards',
#  'PERSONAL',
#  'Buying a painting',
#  'Consol',
#  ' Business Loan',
#  'simplify my life!',
#  'Credit Card Debt',
#  'Restructuring',
#  'Help Me Consolidate!',
#  'Consolidate My Bills',
#  'Paying Off All Cards',
#  'Deb CC Cond',
#  'my consolidation',
#  'My Lending Club loan',
#  'Sunshine',
#  'Moving',
#  'Personal Important loan',
#  'Deck loan',
#  'Help Me Survive Loan',
#  'card payoff',
#  'New Beginning',
#  'Creditcard cleaner',
#  'loan consolidation',
#  'Debt Free',
#  'Disc',
#  'Credit Card Conolidation',
#  'Credit Card Consolidation Loan',
#  'CREDIT CONSOLIDATION ',
#  'Fighting High Interest Rates',
#  'Holidays',
#  'Consolidate Cred Cards',
#  'vincent',
#  'To a better life',
#  'Dream',
#  'Suburban ',
#  'Credit Card Buster',
#  'debt reduction',
#  'Getting Married, want to start new life debt free',
#  'Wedding Fund',
#  'Chase Refi',
#  'Kitchen Repairs',
#  'no more debt!',
#  'Get on Track',
#  'Working Capital Loan',
#  'Loan Consolication',
#  '2010 Consolidation',
#  'Investment Property',
#  'Debt Cons./Website Business Launch',
#  'Credit Cards Consolidation',
#  'small_business',
#  'Debit loan ',
#  'Credit_Card',
#  'Debt Con',
#  'DEBT RELIEF',
#  '2011 dcl',
#  'Paying off CC',
#  'Breather',
#  'Goodbye Prosper, Hello Lending Club',
#  'loan for debt consolidation',
#  'Ready to get out of debt.',
#  'Credit Cnsd',
#  'taking care of business',
#  'Wedding / Consolidation',
#  'simpler life',
#  'dedt consolidation loan',
#  'Consolidation of debt loan',
#  'Primary',
#  'Movement Loan',
#  'my debt consolidation loan',
#  'above ground pool',
#  'Fixing Up Duplex',
#  'Boat - Very Good With Money',
#  'Sustainable Technology',
#  'Need Finances for Wedding! ',
#  'Need to get out of inlaws house',
#  '2011 debt to 1',
#  'My Loan 1',
#  'Recent Graduate - Debt Consolidation',
#  'MY LOAN',
#  'Credit card reduction',
#  'Out of Debt Forever',
#  'Housing',
#  'Card payoff',
#  'LOAN TO ME',
#  'payments',
#  'Time to Change',
#  'Resurfacing',
#  'Consolidating Credit Card Debt',
#  'payoff and remodel',
#  'Freshstart',
#  'Restart DC',
#  'dept consolidation loan',
#  'Combine 2 credit cards into fixed loan',
#  'myloan',
#  "Jay's Debt Consolation",
#  'PAY DEBT',
#  'personal LOAN',
#  'debtfreecc',
#  'Card loan',
#  'MYLOAN',
#  'tried and true',
#  'Clearing Up',
#  'Quid Pro Quo',
#  'chances',
#  "Paul's Personal",
#  'CC CONSOLIDATION',
#  'my personal loan',
#  'kitchen',
#  'Bills Be Gone',
#  'Finances',
#  'easy paments',
#  'Debt Help',
#  'crdit card',
#  'refi loan ',
#  'downpayment ',
#  'Equipment',
#  'The JPA "Hey Debt, Outta My Way" Plan',
#  'just a little behind',
#  'PAY OFF CARDS',
#  'Ditch Revolving Credit',
#  'Bill Consolidation -Debt free by 2015!!!',
#  ...]

# %%
df["title"].nunique()
# Out:
# 48816

# %% [markdown]
# **The title column is simply a string subcategory of the purpose column.Hence we will drop the title column.**

# %%
df.drop("title",axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'earliest_cr_line', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'application_type', 'mort_acc',
#        'pub_rec_bankruptcies', 'address', 'loan_repaid'],
#       dtype='object')

# %%
print(info("mort_acc"))
# Out:
# Number of mortgage accounts.

# %% [markdown]
# **The 'mort_acc' columns**

# %%
df["mort_acc"].value_counts()
# Out:
# mort_acc
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 32.0         2
# 31.0         2
# 23.0         2
# 26.0         2
# 28.0         1
# 30.0         1
# 34.0         1
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)["mort_acc"].sort_values()[:-1]
# Out:
# int_rate               -0.082583
# dti                    -0.025439
# revol_util              0.007514
# pub_rec                 0.011552
# pub_rec_bankruptcies    0.027239
# loan_repaid             0.073111
# open_acc                0.109205
# installment             0.193694
# revol_bal               0.194925
# loan_amnt               0.222315
# annual_inc              0.236320
# total_acc               0.381072
# Name: mort_acc, dtype: float64

# %% [markdown]
# **We can observe that the 'total_acc' feature correlates with the 'mort_acc' upto a significant extinct. We will use 'total_acc' to fill the missing values in 'mort_acc' using fillna() approach. We will group the dataframe by the total_acc and calculate the mean value for the mort_acc per total_acc entry.**

# %%
df["total_acc"].unique()
# Out:
# array([ 25.,  27.,  26.,  13.,  43.,  23.,  15.,  40.,  37.,  61.,  35.,
#         22.,  20.,  36.,  38.,   7.,  18.,  10.,  17.,  29.,  16.,  21.,
#         34.,   9.,  14.,  59.,  41.,  19.,  12.,  30.,  56.,  24.,  28.,
#          8.,  52.,  31.,  44.,  39.,  50.,  11.,  62.,  32.,   5.,  33.,
#         46.,  42.,   6.,  49.,  45.,  57.,  48.,  67.,  47.,  51.,  58.,
#          3.,  55.,  63.,  53.,   4.,  71.,  69.,  54.,  64.,  81.,  72.,
#         60.,  68.,  65.,  73.,  78.,  84.,   2.,  76.,  75.,  79.,  87.,
#         77., 104.,  89.,  70., 105.,  97.,  66., 108.,  74.,  80.,  82.,
#         91.,  93., 106.,  90.,  85.,  88.,  83., 111.,  86., 101., 135.,
#         92.,  94.,  95.,  99., 102., 129., 110., 124., 151., 107., 118.,
#        150., 115., 117.,  96.,  98., 100., 116., 103.])

# %%
array = df.groupby("total_acc")["mort_acc"].mean()

# %%
array
# Out:
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %%
df["mort_acc"].unique()
# Out:
# array([ 0.,  3.,  1.,  4.,  2.,  6.,  5., nan, 10.,  7., 12., 11.,  8.,
#         9., 13., 14., 22., 34., 15., 25., 19., 16., 17., 32., 18., 24.,
#        21., 20., 31., 28., 30., 23., 26., 27.])

# %%
df["mort_acc"]
# Out:
# 0         0.0
# 1         3.0
# 2         0.0
# 3         0.0
# 4         1.0
#          ...
# 396025    0.0
# 396026    1.0
# 396027    0.0
# 396028    5.0
# 396029    NaN
# Name: mort_acc, Length: 396030, dtype: float64

# %%
def fill(col):
    mort_acc = col[0]
    total_acc = col[1]
    if np.isnan(mort_acc):
        return array[total_acc]
    else:
        return mort_acc

# %%
df["mort_acc"] = df[["mort_acc","total_acc"]].apply(fill, axis=1)
# Out:
# /var/folders/23/80k7f5gx2wldn_nl5r_nkbhm0000gn/T/ipykernel_20269/1371091181.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mort_acc = col[0]
# /var/folders/23/80k7f5gx2wldn_nl5r_nkbhm0000gn/T/ipykernel_20269/1371091181.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   total_acc = col[1]

# %%
df.isnull().sum()
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# home_ownership            0
# annual_inc                0
# verification_status       0
# issue_d                   0
# loan_status               0
# purpose                   0
# dti                       0
# earliest_cr_line          0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util              276
# total_acc                 0
# initial_list_status       0
# application_type          0
# mort_acc                  0
# pub_rec_bankruptcies    535
# address                   0
# loan_repaid               0
# dtype: int64

# %%
df["mort_acc"]
# Out:
# 0         0.000000
# 1         3.000000
# 2         0.000000
# 3         0.000000
# 4         1.000000
#             ...
# 396025    0.000000
# 396026    1.000000
# 396027    0.000000
# 396028    5.000000
# 396029    1.358013
# Name: mort_acc, Length: 396030, dtype: float64

# %% [markdown]
# **Further 'revol_util' and the 'pub_rec_bankruptcies' have missing data points, but they account for less than 0.5% of the total data. Hence we will go ahead and remove the rows that are have missing values for 'revol_util' and the 'pub_rec_bankruptcies'.**

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# dtype: int64

# %% [markdown]
# ---
# ## Categorical Variables and Dummy Variables
#
# **Now that we're done working with the missing data, we will perform some feature engineering to deal with the categorical columns and convert them into usable data form.**
#
# ---

# %%
df.select_dtypes(include=object).columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %% [markdown]
# ---
# **Let's now go through all the string features to see what we should do with them.**
#
# ---
#
#
# ### Term feature

# %%
df["term"].value_counts()
# Out:
# term
#  36 months    301247
#  60 months     93972
# Name: count, dtype: int64

# %%
df['term'].head()
# Out:
# 0     36 months
# 1     36 months
# 2     36 months
# 3     36 months
# 4     60 months
# Name: term, dtype: object

# %%
def term_c(obj):
    l= obj.split()
    return int(l[0])

# %%
df['term'] = df["term"].apply(term_c)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'earliest_cr_line', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'application_type', 'mort_acc',
#        'pub_rec_bankruptcies', 'address', 'loan_repaid'],
#       dtype='object')

# %% [markdown]
# ### grade feature
#
# **We know that grade is part of sub_grade, so we will just drop the grade feature.**

# %%
df.drop("grade", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'sub_grade',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'earliest_cr_line', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'application_type', 'mort_acc',
#        'pub_rec_bankruptcies', 'address', 'loan_repaid'],
#       dtype='object')

# %% [markdown]
# **Converting the subgrade into dummy variables.**

# %%
new_df = pd.get_dummies(df["sub_grade"], drop_first=True )

# %%
df= pd.concat([df,new_df], axis=1)

# %%
df.drop("sub_grade",axis=1,inplace=True)

# %%
df.select_dtypes(include=object).columns
# Out:
# Index(['home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'purpose', 'earliest_cr_line', 'initial_list_status',
#        'application_type', 'address'],
#       dtype='object')

# %% [markdown]
# ### verification_status, application_type,initial_list_status,purpose
# **Converting these columns: ['verification_status', 'application_type','initial_list_status','purpose'] into dummy variables and concatenate them with the original dataframe.**

# %%
df[['verification_status', 'application_type','initial_list_status','purpose']].head()
# Out:
#   verification_status application_type initial_list_status             purpose
# 0        Not Verified       INDIVIDUAL                   w            vacation
# 1        Not Verified       INDIVIDUAL                   f  debt_consolidation
# 2     Source Verified       INDIVIDUAL                   f         credit_card
# 3        Not Verified       INDIVIDUAL                   f         credit_card
# 4            Verified       INDIVIDUAL                   f         credit_card

# %%
dummies = pd.get_dummies(df[['verification_status', 'application_type','initial_list_status','purpose' ]],drop_first=True)
df = df.drop(['verification_status', 'application_type','initial_list_status','purpose'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df.select_dtypes(["object"]).columns
# Out:
# Index(['home_ownership', 'issue_d', 'loan_status', 'earliest_cr_line',
#        'address'],
#       dtype='object')

# %% [markdown]
# ### home_ownership
# **Review the value_counts for the home_ownership column.**

# %%
df.home_ownership.value_counts()
# Out:
# home_ownership
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          110
# NONE            29
# ANY              3
# Name: count, dtype: int64

# %% [markdown]
# **Convert 'home_ownership' to dummy variables, but replace NONE and ANY with OTHER, so that we have just 4 categories, MORTGAGE, RENT, OWN, OTHER.**

# %%
def fun(string):
    if string == 'NONE' or string=='ANY':
        return 'OTHER'
    else:
        return string

# %%
df['home_ownership'] = df['home_ownership'].apply(lambda x: fun(x))

# %%
df.home_ownership.value_counts()
# Out:
# home_ownership
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          142
# Name: count, dtype: int64

# %%
dummies = pd.get_dummies(df["home_ownership"], drop_first=True)

# %%
df = pd.concat([df.drop("home_ownership", axis=1), dummies], axis=1)

# %%
df.head(5)
# Out:
#    loan_amnt  term  int_rate  installment  annual_inc   issue_d  loan_status  \
# 0    10000.0    36     11.44       329.48    117000.0  Jan-2015   Fully Paid
# 1     8000.0    36     11.99       265.68     65000.0  Jan-2015   Fully Paid
# 2    15600.0    36     10.49       506.97     43057.0  Jan-2015   Fully Paid
# 3     7200.0    36      6.49       220.65     54000.0  Nov-2014   Fully Paid
# 4    24375.0    60     17.27       609.33     55000.0  Apr-2013  Charged Off
#
#      dti earliest_cr_line  open_acc  ...  purpose_medical  purpose_moving  \
# 0  26.24         Jun-1990      16.0  ...            False           False
# 1  22.05         Jul-2004      17.0  ...            False           False
# 2  12.79         Aug-2007      13.0  ...            False           False
# 3   2.60         Sep-2006       6.0  ...            False           False
# 4  33.95         Mar-1999      13.0  ...            False           False
#
#    purpose_other  purpose_renewable_energy  purpose_small_business  \
# 0          False                     False                   False
# 1          False                     False                   False
# 2          False                     False                   False
# 3          False                     False                   False
# 4          False                     False                   False
#
#    purpose_vacation purpose_wedding  OTHER    OWN   RENT
# 0              True           False  False  False   True
# 1             False           False  False  False  False
# 2             False           False  False  False   True
# 3             False           False  False  False   True
# 4             False           False  False  False  False
#
# [5 rows x 73 columns]

# %% [markdown]
# ### 'address' columns
# **Feature engineering zip code column from the address in the data set. Creating a column 'zip_code' that extracts the zip code from the address column.**

# %%
df["address"].head()
# Out:
# 0       0174 Michelle Gateway\nMendozaberg, OK 22690
# 1    1076 Carney Fort Apt. 347\nLoganmouth, SD 05113
# 2    87025 Mark Dale Apt. 269\nNew Sabrina, WV 05113
# 3              823 Reid Ford\nDelacruzside, MA 00813
# 4               679 Luna Roads\nGreggshire, VA 11650
# Name: address, dtype: object

# %%
def zip(add):
    zipcode = add.split()
    return int(zipcode[-1])

# %%
zip('0174 Michelle Gateway\nMendozaberg, OK 22690')
# Out:
# 22690

# %%
df['zipcode'] = df["address"].apply(lambda x: zip(x))

# %%
df["zipcode"].head()
# Out:
# 0    22690
# 1     5113
# 2     5113
# 3      813
# 4    11650
# Name: zipcode, dtype: int64

# %%
df.zipcode.value_counts()
# Out:
# zipcode
# 70466    56880
# 22690    56413
# 30723    56402
# 48052    55811
# 813      45725
# 29597    45393
# 5113     45300
# 11650    11210
# 93700    11126
# 86630    10959
# Name: count, dtype: int64

# %% [markdown]
# **Now coonverting this zip_code column into dummy variables.**

# %% [markdown]
# ### Column 'issue_d '
#
# **We wouldn't have an issue_date unless a loan is issued, hence we will drop this feature.**

# %%
df.issue_d.head()
# Out:
# 0    Jan-2015
# 1    Jan-2015
# 2    Jan-2015
# 3    Nov-2014
# 4    Apr-2013
# Name: issue_d, dtype: object

# %%
df.drop("issue_d",axis=1,inplace=True)

# %% [markdown]
# ### Column 'earliest_cr_line'
# **It looks like this columns elements are historical time stamp feature. hence we will go ahead to extract the year from this feature and then convert it to a numeric feature.**

# %%
df["earliest_cr_line"].head()
# Out:
# 0    Jun-1990
# 1    Jul-2004
# 2    Aug-2007
# 3    Sep-2006
# 4    Mar-1999
# Name: earliest_cr_line, dtype: object

# %%
def year(time):
    year = time.split('-')
    return int(year[-1])

# %%
year('Jun-1990')
# Out:
# 1990

# %%
df["earliest_cr_year"] = df["earliest_cr_line"].apply(lambda x: year(x))

# %%
df.earliest_cr_year.head()
# Out:
# 0    1990
# 1    2004
# 2    2007
# 3    2006
# 4    1999
# Name: earliest_cr_year, dtype: int64

# %%
df.drop("earliest_cr_line",axis=1,inplace=True)

# %%
df.select_dtypes([object]).columns
# Out:
# Index(['loan_status', 'address'], dtype='object')

# %%
df.drop("address",axis=1,inplace=True)

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# **Importing train_test_split from sklearn.**

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
df1 = df.copy()

# %%
len(df)
# Out:
# 395219

# %% [markdown]
# **Drop 'loan_status' as 'loan_repaid' are essentially the same**

# %%
df1.drop("loan_status", axis =1, inplace=True)

# %%
df2=df1.sample(frac=0.1,random_state=101)

# %%
X = df2.drop("loan_repaid",axis=1)
X.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'mort_acc', 'pub_rec_bankruptcies', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2',
#        'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4',
#        'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1',
#        'G2', 'G3', 'G4', 'G5', 'verification_status_Source Verified',
#        'verification_status_Verified', 'application_type_INDIVIDUAL',
#        'application_type_JOINT', 'initial_list_status_w',
#        'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement', 'purpose_house',
#        'purpose_major_purchase', 'purpose_medical', 'purpose_moving',
#        'purpose_other', 'purpose_renewable_energy', 'purpose_small_business',
#        'purpose_vacation', 'purpose_wedding', 'OTHER', 'OWN', 'RENT',
#        'zipcode', 'earliest_cr_year'],
#       dtype='object')

# %%
X
# Out:
#         loan_amnt  term  int_rate  installment  annual_inc    dti  open_acc  \
# 204901    14800.0    36     18.49       538.71    104540.0  13.12      10.0
# 226870    31000.0    60     17.57       779.97    122000.0  27.46      20.0
# 241733    22000.0    60      7.89       444.93     71400.0  21.29       9.0
# 225481    20000.0    36     10.78       652.70    100000.0  17.86      14.0
# 104657    18625.0    60     17.57       468.61     41500.0  18.80      20.0
# ...           ...   ...       ...          ...         ...    ...       ...
# 325989    24000.0    36      6.97       740.73    180000.0   2.65      10.0
# 123186    12800.0    36     14.47       440.41     62000.0  20.54      10.0
# 33157     16200.0    60     20.75       435.99     45000.0  26.51      19.0
# 232425    21000.0    60     20.99       568.01     98000.0  17.63      14.0
# 160674     5600.0    36     10.64       182.39     65000.0   9.16       7.0
#
#         pub_rec  revol_bal  revol_util  ...  purpose_other  \
# 204901      0.0    21241.0        60.9  ...          False
# 226870      0.0    36941.0        55.1  ...          False
# 241733      0.0     5212.0        41.7  ...          False
# 225481      0.0    11139.0        38.9  ...          False
# 104657      0.0    27975.0        38.9  ...          False
# ...         ...        ...         ...  ...            ...
# 325989      0.0     4604.0         8.5  ...          False
# 123186      0.0    16704.0        91.3  ...          False
# 33157       1.0     9410.0        57.7  ...          False
# 232425      0.0    34456.0        83.4  ...          False
# 160674      0.0    12931.0        72.6  ...          False
#
#         purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 204901                     False                   False             False
# 226870                     False                   False             False
# 241733                     False                   False             False
# 225481                     False                   False             False
# 104657                     False                   False             False
# ...                          ...                     ...               ...
# 325989                     False                   False             False
# 123186                     False                   False             False
# 33157                      False                   False             False
# 232425                     False                   False             False
# 160674                     False                   False             False
#
#         purpose_wedding  OTHER    OWN   RENT  zipcode  earliest_cr_year
# 204901            False  False  False   True     5113              1992
# 226870            False  False  False  False    29597              1996
# 241733            False  False  False   True      813              2003
# 225481            False  False  False  False    22690              1994
# 104657            False  False  False  False    29597              1993
# ...                 ...    ...    ...    ...      ...               ...
# 325989            False  False  False  False    70466              1984
# 123186            False  False  False  False    30723              2001
# 33157             False  False   True  False    70466              2002
# 232425            False  False  False   True      813              2000
# 160674            False  False  False   True     5113              1996
#
# [39522 rows x 70 columns]

# %%
X = X.values

# %%
X[1]
# Out:
# array([31000.0, 60, 17.57, 779.97, 122000.0, 27.46, 20.0, 0.0, 36941.0,
#        55.1, 36.0, 4.0, 0.0, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, True, True, False, True, False, True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, 29597, 1996], dtype=object)

# %%
y= df2["loan_repaid"].values

# %%
len(y)
# Out:
# 39522

# %%
len(df2)
# Out:
# 39522

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %%
X_train
# Out:
# array([[22000.0, 60, 19.72, ..., True, 30723, 1997],
#        [4800.0, 36, 18.55, ..., True, 22690, 2001],
#        [9600.0, 36, 16.29, ..., True, 29597, 2006],
#        ...,
#        [25000.0, 60, 17.57, ..., False, 5113, 1999],
#        [31925.0, 36, 13.49, ..., False, 29597, 2005],
#        [7500.0, 36, 13.47, ..., False, 813, 1996]], dtype=object)

# %%
X_train[1]
# Out:
# array([4800.0, 36, 18.55, 174.86, 35320.0, 24.37, 24.0, 0.0, 8396.0, 38.3,
#        28.0, 0.0, 0.0, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, True, True, False, False, True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, True, 22690, 2001], dtype=object)

# %% [markdown]
# **Scaling the dataset**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
prepross = MinMaxScaler()

# %%
X_train = prepross.fit_transform(X_train)
X_test = prepross.transform(X_test)

# %% [markdown]
# **Importing modules and libraries for deep learning models**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.constraints import  max_norm
# Out:
# 2023-11-05 23:48:14.934278: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = Sequential()
model.add(Dense(78, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(39, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(19, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x=X_train,y=y_train, epochs=25, batch_size=256, validation_data=(X_test,y_test), verbose=1)
# Out:
# Epoch 1/25
# 124/124 [==============================] - 4s 15ms/step - loss: 0.5183 - accuracy: 0.7845 - val_loss: 0.4370 - val_accuracy: 0.8014
# Epoch 2/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.4388 - accuracy: 0.8090 - val_loss: 0.4176 - val_accuracy: 0.8305
# Epoch 3/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.4285 - accuracy: 0.8220 - val_loss: 0.4100 - val_accuracy: 0.8325
# Epoch 4/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.4195 - accuracy: 0.8291 - val_loss: 0.4032 - val_accuracy: 0.8433
# Epoch 5/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.4106 - accuracy: 0.8378 - val_loss: 0.3930 - val_accuracy: 0.8443
# Epoch 6/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.4004 - accuracy: 0.8437 - val_loss: 0.3892 - val_accuracy: 0.8497
# Epoch 7/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3938 - accuracy: 0.8480 - val_loss: 0.3806 - val_accuracy: 0.8519
# Epoch 8/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3871 - accuracy: 0.8506 - val_loss: 0.3744 - val_accuracy: 0.8536
# Epoch 9/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3785 - accuracy: 0.8537 - val_loss: 0.3729 - val_accuracy: 0.8538
# Epoch 10/25
# 124/124 [==============================] - 1s 6ms/step - loss: 0.3767 - accuracy: 0.8555 - val_loss: 0.3708 - val_accuracy: 0.8543
# Epoch 11/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3721 - accuracy: 0.8562 - val_loss: 0.3690 - val_accuracy: 0.8543
# Epoch 12/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3705 - accuracy: 0.8579 - val_loss: 0.3687 - val_accuracy: 0.8538
# Epoch 13/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3660 - accuracy: 0.8581 - val_loss: 0.3683 - val_accuracy: 0.8552
# Epoch 14/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3674 - accuracy: 0.8587 - val_loss: 0.3682 - val_accuracy: 0.8541
# Epoch 15/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3653 - accuracy: 0.8587 - val_loss: 0.3689 - val_accuracy: 0.8554
# Epoch 16/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3651 - accuracy: 0.8590 - val_loss: 0.3671 - val_accuracy: 0.8550
# Epoch 17/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3624 - accuracy: 0.8598 - val_loss: 0.3669 - val_accuracy: 0.8550
# Epoch 18/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3612 - accuracy: 0.8596 - val_loss: 0.3674 - val_accuracy: 0.8549
# Epoch 19/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3605 - accuracy: 0.8597 - val_loss: 0.3674 - val_accuracy: 0.8545
# Epoch 20/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3601 - accuracy: 0.8597 - val_loss: 0.3670 - val_accuracy: 0.8552
# Epoch 21/25
# 124/124 [==============================] - 1s 6ms/step - loss: 0.3587 - accuracy: 0.8607 - val_loss: 0.3674 - val_accuracy: 0.8550
# Epoch 22/25
# 124/124 [==============================] - 1s 6ms/step - loss: 0.3573 - accuracy: 0.8610 - val_loss: 0.3671 - val_accuracy: 0.8546
# Epoch 23/25
# 124/124 [==============================] - 1s 6ms/step - loss: 0.3557 - accuracy: 0.8604 - val_loss: 0.3670 - val_accuracy: 0.8545
# Epoch 24/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3566 - accuracy: 0.8607 - val_loss: 0.3689 - val_accuracy: 0.8545
# Epoch 25/25
# 124/124 [==============================] - 1s 5ms/step - loss: 0.3540 - accuracy: 0.8613 - val_loss: 0.3679 - val_accuracy: 0.8541

# %%
from tensorflow.keras.models import load_model

# %%
model.save("/Users/akshayshendre/Desktop/Apploan/models/model.h5")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
losses = pd.DataFrame(model.history.history)

# %% [markdown]
# **Plotting plot for loss and val_loss**

# %%
losses[['loss',"val_loss"]].plot();

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
predictions = model.predict(X_test)
# Out:
# 248/248 [==============================] - 1s 2ms/step

# %%
predictions = np.where(predictions > 0.5,1,0)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.28      0.43      1570
#            1       0.85      1.00      0.92      6335
#
#     accuracy                           0.85      7905
#    macro avg       0.90      0.64      0.67      7905
# weighted avg       0.87      0.85      0.82      7905

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[ 438, 1132],
#        [  21, 6314]])

# %%
print(accuracy_score(y_test,predictions))
# Out:
# 0.8541429475015813

# %% [markdown]
# **We have achieved an impressive accuracy of 85% using our feature engineering and deep learning model approach.**

# %%
model = load_model("/Users/akshayshendre/Desktop/Apploan/models/model.h5")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 78)                5538
#
#  dropout (Dropout)           (None, 78)                0
#
#  dense_1 (Dense)             (None, 39)                3081
#
#  dropout_1 (Dropout)         (None, 39)                0
#
#  dense_2 (Dense)             (None, 19)                760
#
#  dropout_2 (Dropout)         (None, 19)                0
#
#  dense_3 (Dense)             (None, 1)                 20
#
# =================================================================
# Total params: 9399 (36.71 KB)
# Trainable params: 9399 (36.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
